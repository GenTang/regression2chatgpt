# %%
import torch
import torch.nn.functional as F
import string

# Define the vocabulary
char2indx = {s: i for i, s in enumerate(sorted(string.ascii_lowercase))}
char2indx

# %%
example = list('love')
example

# %%
# Convert the text to numeric IDs using the vocabulary
idx = []

for i in example:
    idx.append(char2indx[i])

idx = torch.tensor(idx)
idx, idx.shape

# %%
# Convert text into a two-dimensional tensor using one-hot encoding
num_claz = 26
dims = 5
x = F.one_hot(idx, num_classes=num_claz).float()
x, x.shape

# %%
# A token embedding is essentially tensor multiplication
x                                 # ( 4, 26)
W = torch.randn((num_claz, dims)) # (26,  5)
x @ W                             # ( 4,  5)

# %%
# Equivalent to the tensor multiplication above, but with a friendlier implementation
# This is more efficient because idx has fewer dimensions and requires no one-hot encoding
idx    # ( 4)
W      # (26, 5)
W[idx] # ( 4, 5)

# %%
# Token-embedding implementation example
class Embedding:
    
    def __init__(self, num_embeddings, embedding_dim):
        self.weight = torch.randn((num_embeddings, embedding_dim))

    def __call__(self, idx):
        self.out = self.weight[idx]
        return self.out

    def parameters(self):
        return [self.weight]

# %%
# Correct usage
emb = Embedding(num_claz, dims)
emb(idx), idx.shape, emb(idx).shape

# %%
# A higher-dimensional example
# Treat bidx as 10 character sequences, each with length 11
bidx = torch.randint(0, num_claz, (10, 11))
bidx.shape, emb(bidx).shape

# %%
# Incorrect usage
# x is the result of one-hot encoding
emb(x.int())
